# %% [markdown]
# ## Inverse Cooking: Recipe Generation from Food Images

# %%
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import numpy as np
import os
from args import get_parser
import pickle
from model import get_model
from torchvision import transforms
from utils.output_utils import prepare_output
from PIL import Image
import time

# %% [markdown]
# Set ```data_dir``` to the path including vocabularies and model checkpoint

# %%
data_dir = '../data'

# %%
# code will run in gpu if available and if the flag is set to True, else it will run on cpu
use_gpu = False
device = torch.device('cuda' if torch.cuda.is_available() and use_gpu else 'cpu')
map_loc = None if torch.cuda.is_available() and use_gpu else 'cpu'

# %%
# code below was used to save vocab files so that they can be loaded without Vocabulary class
#ingrs_vocab = pickle.load(open(os.path.join(data_dir, 'final_recipe1m_vocab_ingrs.pkl'), 'rb'))
#ingrs_vocab = [min(w, key=len) if not isinstance(w, str) else w for w in ingrs_vocab.idx2word.values()]
#vocab = pickle.load(open(os.path.join(data_dir, 'final_recipe1m_vocab_toks.pkl'), 'rb')).idx2word
#pickle.dump(ingrs_vocab, open('../demo/ingr_vocab.pkl', 'wb'))
#pickle.dump(vocab, open('../demo/instr_vocab.pkl', 'wb'))

ingrs_vocab = pickle.load(open(os.path.join(data_dir, 'ingr_vocab.pkl'), 'rb'))
vocab = pickle.load(open(os.path.join(data_dir, 'instr_vocab.pkl'), 'rb'))

ingr_vocab_size = len(ingrs_vocab)
instrs_vocab_size = len(vocab)
output_dim = instrs_vocab_size

# %%
print (instrs_vocab_size, ingr_vocab_size)
print(ingrs_vocab[:300])
# Out:
# 23231 1488

# %%
t = time.time()
import sys; sys.argv=['']; del sys
args = get_parser()
args.maxseqlen = 15
args.ingrs_only=False
model = get_model(args, ingr_vocab_size, instrs_vocab_size)
# Load the trained model parameters
model_path = os.path.join(data_dir, 'modelbest.ckpt')
model.load_state_dict(torch.load(model_path, map_location=map_loc))
model.to(device)
model.eval()
model.ingrs_only = False
model.recipe_only = False
print ('loaded model')
print ("Elapsed time:", time.time() -t)
# Out:
# loaded model
# Elapsed time: 4.219473838806152

# %%
transf_list_batch = []
transf_list_batch.append(transforms.ToTensor())
transf_list_batch.append(transforms.Normalize((0.485, 0.456, 0.406), 
                                              (0.229, 0.224, 0.225)))
to_input_transf = transforms.Compose(transf_list_batch)

# %%
greedy = [True, False, False, False]
beam = [-1, -1, -1, -1]
temperature = 1.0
numgens = len(greedy)

# %% [markdown]
# Set ```use_urls = True``` to get recipes for images in ```demo_urls```.
#
# You can also set ```use_urls = False``` and get recipes for images in the path in ```data_dir/test_imgs```.

# %%
import requests
from io import BytesIO
import random
from collections import Counter
use_urls = False # set to true to load images from demo_urls instead of those in test_imgs folder
show_anyways = False #if True, it will show the recipe even if it's not valid
image_folder = os.path.join(data_dir, 'demo_imgs')

if not use_urls:
    demo_imgs = os.listdir(image_folder)
    random.shuffle(demo_imgs)

demo_urls = ['https://food.fnr.sndimg.com/content/dam/images/food/fullset/2013/12/9/0/FNK_Cheesecake_s4x3.jpg.rend.hgtvcom.826.620.suffix/1387411272847.jpeg',
            'https://www.196flavors.com/wp-content/uploads/2014/10/california-roll-3-FP.jpg']

demo_files = demo_urls if use_urls else demo_imgs

# %%
for img_file in demo_files:
    
    if use_urls:
        response = requests.get(img_file)
        image = Image.open(BytesIO(response.content))
    else:
        image_path = os.path.join(image_folder, img_file)
        image = Image.open(image_path).convert('RGB')
    
    transf_list = []
    transf_list.append(transforms.Resize(256))
    transf_list.append(transforms.CenterCrop(224))
    transform = transforms.Compose(transf_list)
    
    image_transf = transform(image)
    image_tensor = to_input_transf(image_transf).unsqueeze(0).to(device)
    
    plt.imshow(image_transf)
    plt.axis('off')
    plt.show()
    plt.close()
    
    num_valid = 1
    for i in range(numgens):
        with torch.no_grad():
            outputs = model.sample(image_tensor, greedy=greedy[i], 
                                   temperature=temperature, beam=beam[i], true_ingrs=None)
            
        ingr_ids = outputs['ingr_ids'].cpu().numpy()
        recipe_ids = outputs['recipe_ids'].cpu().numpy()
            
        outs, valid = prepare_output(recipe_ids[0], ingr_ids[0], ingrs_vocab, vocab)
        
        if valid['is_valid'] or show_anyways:
            
            print ('RECIPE', num_valid)
            num_valid+=1
            #print ("greedy:", greedy[i], "beam:", beam[i])
    
            BOLD = '\033[1m'
            END = '\033[0m'
            print (BOLD + '\nTitle:' + END,outs['title'])

            print (BOLD + '\nIngredients:'+ END)
            print (', '.join(outs['ingrs']))

            print (BOLD + '\nInstructions:'+END)
            print ('-'+'\n-'.join(outs['recipe']))

            print ('='*20)

        else:
            pass
            print ("Not a valid recipe!")
            print ("Reason: ", valid['reason'])
# Out:
# RECIPE 1
#
# Title: Penne with caramelized onions
#
# Ingredients:
# cheese, pasta, pepper, onion, oil
#
# Instructions:
# -Heat oil in large skillet over medium-high heat.
# -Add onions; cook until golden brown, stirring occasionally, about 15 minutes.
# -Add pasta and cook until heated through, stirring occasionally, about 10 minutes.
# -Season with salt and pepper.
# -Sprinkle with cheese.
# ====================
# RECIPE 2
#
# Title: Mostaccioli with feta and caramelized onions
#
# Ingredients:
# cheese, pasta, pepper, onion, oil
#
# Instructions:
# -Cook pasta in salted water until al dente; drain and toss with oil.
# -Heat large skillet on medium heat.
# -Add onions and toss to combine.
# -Add cheese and cook until cheese is melted and onions are lightly browned.
# -Season with salt and pepper.
# ====================
# RECIPE 3
#
# Title: Rigatoni with cheese and onions
#
# Ingredients:
# cheese, pasta, pepper, onion, oil
#
# Instructions:
# -Cook the rigatoni in a 6- to 8-quart pot of boiling salted water, uncovered, until just tender, about 12 to 20 minutes.
# -Drain and transfer to a large bowl.
# -While the rigatoni is cooking, heat the oil in a medium saucepan over moderately high heat until hot.
# -Add the onion and cook, stirring occasionally, for 6 minutes.
# -Add the red pepper and cook, stirring occasionally, for 2 minutes.
# -Add the pasta to the onion and pepper mixture and toss to coat.
# -Add the cheese and stir until melted.
# ====================
# RECIPE 4
#
# Title: Ziti pasta with ricotta and onion
#
# Ingredients:
# cheese, pasta, pepper, onion, oil
#
# Instructions:
# -Heat oil in large skillet on medium-high heat.
# -Add onions.
# -Cook 15 minutes or until onions are browned, stirring occasionally.
# -Add ziti; toss to coat.
# -Reduce heat to medium-low.
# -Cover; simmer 10 minutes.
# -Meanwhile, cook pasta in large pot of boiling salted water until almost tender, stirring occasionally.
# -Drain pasta; toss with ricotta mixture.
# -Season to taste with salt and pepper.
# ====================
# RECIPE 1
#
# Title: Garlic shrimp scampi
#
# Ingredients:
# shrimp, pepper, butter, clove, oil, salt, pasta, parsley
#
# Instructions:
# -Heat olive oil in a large skillet over medium heat.
# -Cook and stir garlic in hot oil until fragrant, about 1 minute.
# -Stir shrimp into garlic; cook and stir until shrimp are pink and opaque, about 3 minutes.
# -Season with salt and pepper.
# -Stir butter into shrimp mixture until melted and sauce is heated through, about 2 minutes.
# -Stir parsley into shrimp mixture; cook and stir until heated through, about 1 minute.
# ====================
# RECIPE 2
#
# Title: Garlic shrimp scampi
#
# Ingredients:
# shrimp, pepper, butter, clove, oil, salt, pasta, parsley
#
# Instructions:
# -In a large pot of boiling salted water, cook shell pasta until al dente, and drain.
# -While pasta cooks, prepare the shrimp.
# -In a large, deep skillet or dutch oven, heat olive oil over medium heat until hot but not smoking.
# -Add garlic and cook just until fragrant, about 1 minute.
# -Add shrimp and cook, stirring, until shrimp are opaque, about 3 to 4 minutes.
# -Add pasta, butter, red pepper flakes and 1 cup of the parsley; toss to coat, and season with salt and pepper.
# -Transfer pasta to a serving platter and top with remaining parsley.
# ====================
# RECIPE 3
#
# Title: Creamy garlic butter shrimp
#
# Ingredients:
# shrimp, pepper, butter, clove, oil, salt, pasta, parsley
#
# Instructions:
# -Cook pasta per directions on box, drain and rinse with cold water.
# -Heat olive oil in skillet over medium heat, then stir in garlic, shrimp, salt and pepper, then continue stiring until shrimp is pink.
# -Reduce heat to low, add butter and stir for about 1 minute, to melt butter and thicken.
# -Stir in parsley and serve over pasta or pasta.
# -This makes a lot and will not be much more than 1 cup of pasta.
# -Enjoy !
# ====================
# RECIPE 4
#
# Title: Angel hair with shrimp and garlic
#
# Ingredients:
# shrimp, pepper, butter, clove, oil, salt, pasta, parsley
#
# Instructions:
# -Bring a large pot of water to a boil.
# -Cook pasta according to package directions; drain.
# -In a large nonstick skillet, heat olive oil over medium heat.
# -Add garlic and cook 1 to 2 minutes or until tender.
# -Stir in shrimp; cook 1 to 2 minutes or until shrimp are pink.
# -Stir in butter, parsley, and salt; remove from heat.
# -Stir in cooked fettuccine; mix well.
# -Serve immediately.
# ====================
# RECIPE 1
#
# Title: Easy pancakes
#
# Ingredients:
# sugar, flour, egg, salt, butter, baking_powder, milk, oil
#
# Instructions:
# -Mix all ingredients together.
# -Heat skillet and pour 1/4 cup of batter onto skillet.
# -Cook until bubbles form on top.
# -Flip and cook until golden brown.
# ====================
# RECIPE 2
#
# Title: Best scones
#
# Ingredients:
# sugar, flour, egg, salt, butter, baking_powder, milk, oil
#
# Instructions:
# -Preheat oven to 400 degrees.
# -In a large bowl mix flour, baking powder, sugar salt.
# -In another bowl mix together milk, butter and egg.
# -Add wet mixture into dry mixture and stir until dough forms.
# -Knead for 5 minutes on lightly floured surface.
# -Divide dough in half and roll out each half into a circle.
# -Cut each circle into 4 wedges.
# -Transfer to baking trays.
# -Brush scones with beaten egg.
# -Sprinkle with colored sugar or jimmies.
# -Bake for 15 - 20 minutes until cooked.
# ====================
# RECIPE 3
#
# Title: Peanut butter pancakes
#
# Ingredients:
# sugar, flour, egg, salt, butter, baking_powder, milk, oil
#
# Instructions:
# -Heat a lightly oiled griddle or frying pan over medium heat.
# -Sift flour, sugar, baking powder and salt together in a large bowl; set aside.
# -Mix peanut butter, milk, oil and eggs together in a separate bowl.
# -Pour about 1/4 cup of batter onto the griddle, and spread to fit the pancake.
# -Cook until bubbles form in the top of the pancake, 1 to 2 minutes.
# -Flip with a spatula and cook until golden brown, 2 to 3 minutes more.
# -Repeat with remaining batter.
# ====================
# RECIPE 4
#
# Title: Basic scones from alice's
#
# Ingredients:
# sugar, flour, egg, salt, butter, baking_powder, milk, oil
#
# Instructions:
# -Sift dry ingredients together.
# -In a separate bowl beat egg.
# -Mix wet ingredients into dry.
# -Kneed until dough comes together to form a ball, about 4.
# -Roll out to 1/2 cm thickness.
# -Cut with pizza cutter.
# -Brush with beaten egg.
# -Bake in oven preheated to 180c until golden brown.
# ====================
# RECIPE 1
#
# Title: Grilled eggplant and zucchini
#
# Ingredients:
# zucchini, oil, salt, squash, pepper, eggplant
#
# Instructions:
# -Preheat grill to medium-high.
# -Brush eggplant slices with oil and season with salt and pepper.
# -Grill, turning once, until tender and lightly charred, about 10 minutes.
# -Transfer to a platter and let cool.
# -Cut into 1/2-inch slices.
# -Serve with grilled zucchini.
# ====================
# RECIPE 2
#
# Title: Grilled eggplant and squash with zucchini
#
# Ingredients:
# zucchini, oil, salt, squash, pepper, eggplant
#
# Instructions:
# -Slice the eggplant lengthwise into 1/4 thick slices and then into 3/4-inch thick slices.
# -In a small bowl, whisk the olive oil with the salt, pepper and crushed red pepper; set aside.
# -Heat a gas grill or charcoal grill to medium heat.
# -Brush the eggplant slices with the olive oil and grill until browned on the bottom and tender, about 4 minutes per side.
# -Brush the zucchini slices with the mixture and grill until browned and tender, about 4 minutes longer.
# ====================
# RECIPE 3
#
# Title: Grilled eggplant and squash
#
# Ingredients:
# zucchini, oil, salt, squash, pepper, eggplant
#
# Instructions:
# -Heat a grill to medium-high and brush the grates with olive oil.
# -Cut each slice of eggplant into quarters and grill on both sides until browned.
# -Season with salt and pepper and grill until tender, about 5 to 7 minutes.
# -Slice each piece into quarters.
# -Serve hot with a drizzle of olive oil on top if desired.
# ====================
# RECIPE 4
#
# Title: Eggplant and zucchini saute
#
# Ingredients:
# zucchini, oil, salt, squash, pepper, eggplant
#
# Instructions:
# -Cut off top 1/4 inch of eggplant with a vegetable peeler; remove center core from eggplant.
# -Cut each half crosswise in half.
# -Cut each half lengthwise into 8 pieces.
# -Heat 1 tablespoon oil in large nonstick skillet over medium-high heat.
# -Add zucchini, squash, and 1/4 teaspoon salt; saute 5 minutes, stirring frequently.
# -Stir in remaining 1 tablespoon oil.
# -Serve immediately.
# ====================
# RECIPE 1
#
# Title: Avocado egg salad sandwich
#
# Ingredients:
# avocado, bread, tomato, mayonnaise, pepper, egg, salt
#
# Instructions:
# -Toast bread.
# -Spread mayonnaise on one side of each slice.
# -Place avocado slices on one slice of bread.
# -Top with tomato slices and salt and pepper.
# -Top with other slice of bread.
# ====================
# RECIPE 2
#
# Title: Avocado egg toast with chipotle mayonnaise
#
# Ingredients:
# avocado, bread, tomato, mayonnaise, pepper, egg, salt
#
# Instructions:
# -Toast bread
# -Spread chipotle mayo onto the bread
# -Top tomato slices with avocado slices then season with salt and pepper
# ====================
# RECIPE 3
#
# Title: Avocado egg salad sandwich
#
# Ingredients:
# avocado, bread, tomato, mayonnaise, pepper, egg, salt
#
# Instructions:
# -Toast bread and spread avocado with tomato and sprinkle with lemon pepper.
# -Top with sliced boiled eggs.
# -Salt and pepper to taste.
# ====================
# RECIPE 4
#
# Title: Scrambled eggs with avocado and tomato
#
# Ingredients:
# avocado, bread, tomato, mayonnaise, pepper, egg, salt
#
# Instructions:
# -Beat egg yolks with salt and pepper.
# -Add mayonnaise.
# -Slice tomato and avocado.
# -Spread egg mixture on one side of toasted bread.
# ====================
# RECIPE 1
#
# Title: Chicken enchiladas
#
# Ingredients:
# cheese, tortilla, onion, cream, enchilada_sauce, chicken, chili, beans, pepper, tomato, cumin
#
# Instructions:
# -Preheat oven to 350 degrees.
# -In a large bowl, combine chicken, beans, tomatoes, onion, green chilies, cumin, and chili powder.
# -Spoon about 1/4 cup of the chicken mixture down the center of each tortilla.
# -Roll up and place seam side down in a greased 13x9 baking dish.
# -Pour enchilada sauce over enchiladas.
# -Sprinkle with cheese.
# -Bake uncovered for 20 minutes.
# ====================
# RECIPE 2
#
# Title: Black bean chicken enchiladas with sour cream
#
# Ingredients:
# cheese, tortilla, onion, cream, enchilada_sauce, chicken, chili, beans, pepper, tomato, cumin
#
# Instructions:
# -Combine first 4 ingredients.
# -Spoon 1/4 cup chicken mixture down center of each tortilla; roll up.
# -Place, seam sides down, in 13x9 baking dish coated with cooking spray.
# -Top with remaining enchilada sauce and cheese.
# -Cover; refrigerate at least 4 hours or overnight.
# -Bake, uncovered, at 350 degrees f for 30 minutes or until hot.
# -Garnish with remaining 1 cup onions.
# ====================
# RECIPE 3
#
# Title: Chicken chili pie
#
# Ingredients:
# cheese, tortilla, onion, cream, enchilada_sauce, chicken, chili, beans, pepper, tomato, cumin
#
# Instructions:
# -In large saucepan cook onion and green pepper in 3 tablespoons of the dressing and the chili powder until onion is tender but not browned.
# -Mix chicken, tomato paste, cumin and remaining dressing and bring to a boil.
# -Reduce heat; simmer, covered about 10 minutes, stirring occasionally.
# -Stir in beans and cook another 5 minutes.
# -Spoon 1/2 of the enchilada sauce into bottom of a 9-inch deep-dish or 10-inch deep-dish pie plate.
# -Spoon 1/3 of the chicken mixture into each tortilla.
# -Sprinkle evenly with cheese.
# -Cover with remaining enchilada sauce.
# -Bake at 375 degrees for 25 minutes or until hot.
# -Serve with sour cream.
# ====================
# Not a valid recipe!
# Reason:  no eos found
